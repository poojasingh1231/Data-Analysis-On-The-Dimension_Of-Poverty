# %%
#import libraries for basic operations
import numpy as np
import pandas as pd
import dabl



#for data visualizations
import plotly
from plotly.offline import iplot
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

#for interactivity
import ipywidgets
from ipywidgets import interact
from ipywidgets import interact_manual

# %%
#Lets reads the dataset
country=pd.read_csv('MPI_national.csv',engine='python')

# %%
#Lets check the shape of the dataset
country.shape
# Out:
# (102, 8)

# %%
#Top five database record
country.head()
# Out:
#    ISO     Country  MPI Urban  Headcount Ratio Urban  \
# 0  KAZ  Kazakhstan      0.000                    0.0
# 1  SRB      Serbia      0.000                    0.1
# 2  KGZ  Kyrgyzstan      0.000                    0.1
# 3  TUN     Tunisia      0.000                    0.1
# 4  ARM     Armenia      0.001                    0.2
#
#    Intensity of Deprivation Urban  MPI Rural  Headcount Ratio Rural  \
# 0                            33.3      0.000                   0.09
# 1                            41.4      0.002                   0.50
# 2                            40.2      0.003                   0.70
# 3                            35.6      0.012                   3.18
# 4                            33.3      0.001                   0.39
#
#    Intensity of Deprivation Rural
# 0                            33.3
# 1                            40.3
# 2                            37.1
# 3                            38.7
# 4                            36.9

# %%
#Last five database record
country.tail()
# Out:
#      ISO                   Country  MPI Urban  Headcount Ratio Urban  \
# 97   CAF  Central African Republic      0.289                   58.2
# 98   LBR                   Liberia      0.290                   60.5
# 99   SOM                   Somalia      0.293                   55.9
# 100  TCD                      Chad      0.351                   64.8
# 101  SSD               South Sudan      0.459                   82.5
#
#      Intensity of Deprivation Urban  MPI Rural  Headcount Ratio Rural  \
# 97                             49.7      0.519                  89.79
# 98                             48.0      0.481                  84.86
# 99                             52.4      0.651                  96.92
# 100                            54.1      0.609                  93.41
# 101                            55.7      0.591                  94.00
#
#      Intensity of Deprivation Rural
# 97                             57.8
# 98                             56.6
# ...

# %%
#Countries present in the data
country['Country'].nunique()
# Out:
# 102

# %%
country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ISO                             102 non-null    object
#  1   Country                         102 non-null    object
#  2   MPI Urban                       102 non-null    float64
#  3   Headcount Ratio Urban           102 non-null    float64
#  4   Intensity of Deprivation Urban  102 non-null    float64
#  5   MPI Rural                       102 non-null    float64
#  6   Headcount Ratio Rural           102 non-null    float64
#  7   Intensity of Deprivation Rural  102 non-null    float64
# dtypes: float64(6), object(2)
# memory usage: 6.5+ KB

# %%
#To check country datatype
country.dtypes
# Out:
# ISO                                object
# Country                            object
# MPI Urban                         float64
# Headcount Ratio Urban             float64
# Intensity of Deprivation Urban    float64
# MPI Rural                         float64
# Headcount Ratio Rural             float64
# Intensity of Deprivation Rural    float64
# dtype: object

# %%
#Inferential Statistics of the data
x=country.cov()
x.style.bar(color=['red', 'yellow'], align='mid')
# Out:
# <style  type="text/css" >
#     #T_51beeaf4_b62b_11ea_bc72_72c94e85ea33row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 0.3%, transparent 0.3%);
#         }    #T_51beeaf4_b62b_11ea_bc72_72c94e85ea33row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 0.3%, transparent 0.3%);
#         }    #T_51beeaf4_b62b_11ea_bc72_72c94e85ea33row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 0.3%, transparent 0.3%);
#         }    #T_51beeaf4_b62b_11ea_bc72_72c94e85ea33row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,yellow 0.3%, transparent 0.3%);
#         }    #T_51beeaf4_b62b_11ea_bc72_72c94e85ea33row0_col4 {
#             width:  10em;
#              height:  80%;
# ...

# %%
x=country.corr()
x.style.bar(color=['red', 'green'], align='mid')
# Out:
# <style  type="text/css" >
#     #T_51cf4890_b62b_11ea_84b3_72c94e85ea33row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 100.0%, transparent 100.0%);
#         }    #T_51cf4890_b62b_11ea_84b3_72c94e85ea33row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 99.6%, transparent 99.6%);
#         }    #T_51cf4890_b62b_11ea_84b3_72c94e85ea33row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 88.0%, transparent 88.0%);
#         }    #T_51cf4890_b62b_11ea_84b3_72c94e85ea33row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 92.2%, transparent 92.2%);
#         }    #T_51cf4890_b62b_11ea_84b3_72c94e85ea33row0_col4 {
#             width:  10em;
#              height:  80%;
# ...

# %%
x=country.describe()
x.style.bar(color=['lightblue'], align='mid')
# Out:
# <style  type="text/css" >
#     #T_51e70fe2_b62b_11ea_a4bf_72c94e85ea33row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#         }    #T_51e70fe2_b62b_11ea_a4bf_72c94e85ea33row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#         }    #T_51e70fe2_b62b_11ea_a4bf_72c94e85ea33row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#         }    #T_51e70fe2_b62b_11ea_a4bf_72c94e85ea33row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#         }    #T_51e70fe2_b62b_11ea_a4bf_72c94e85ea33row0_col4 {
#             width:  10em;
#              height:  80%;
# ...

# %%
#Lets check the columns in the subnational and national data
print("columns in the national data:\n\n", country.columns, '\n')
# Out:
# columns in the national data:
#
#  Index(['ISO', 'Country', 'MPI Urban', 'Headcount Ratio Urban',
#        'Intensity of Deprivation Urban', 'MPI Rural', 'Headcount Ratio Rural',
#        'Intensity of Deprivation Rural'],
#       dtype='object')

# %%
plt.rcParams['figure.figsize']=(9, 6)
sns.heatmap(country.cov(),
           cmap='Reds',
           annot=True)
plt.title('Covariance in the National Data', fontsize=20)
plt.show()

# %%
plt.rcParams['figure.figsize']=(9,6)
sns.heatmap(country.corr(),
           cmap='YlOrBr_r',
           annot=True)
plt.title('Correalation in the national data, fontsize=20')
plt.show()

# %%
plt.rcParams['figure.figsize']=(8, 7)
sns.pairplot(country, diag_kind="kde")
plt.title('Pairplot for the MPI National Data', fontsize=20)
plt.show()

# %% [markdown]
# ---

# %%
#Variable Analysis

# %%
#Lets check the univariate analysis

plt.rcParams['figure.figsize']=(16, 6)
sns.distplot(country['MPI Urban'], color='blue')
plt.title('Distribution of the Multi Dimentional Index in Urban Area', fontsize=20)
plt.show()

# %%
#Lets check the univariate analysis
plt.rcParams['figure.figsize']=(16, 6)
sns.distplot(country['MPI Rural'], color='Green')
plt.title('Distributio of the Multi Dimensional Index in Rural Area', fontsize=20)
plt.show()

# %%
#Lets check the univariate analysis

plt.rcParams['figure.figsize']=(16, 6)
sns.distplot(country['Headcount Ratio Urban'], color='black')
plt.title('Distribution of the Headcount Ratio in Rural Area', fontsize=20)
plt.show()

# %%
#Lets check the univariate analysis

plt.rcParams['figure.figsize']=(16, 6)
sns.distplot(country['Headcount Ratio Rural'], color='crimson')
plt.title('Distribution of the Headcount Ratio in Rural Area', fontsize=20)
plt.show()

# %%
#Intensity of Deprivation Urban

plt.rcParams['figure.figsize']=(16, 6)
sns.distplot(country['Intensity of Deprivation Urban'], color='darkblue')
plt.title('Distribution of the Intensity of Deprivation in Urban Area', fontsize=20)
plt.show()

# %%
#Intensity of Deprivation Rural Area

plt.rcParams['figure.figsize']=(16, 6)
sns.distplot(country['Intensity of Deprivation Rural'], color='Brown')
plt.title('Distribution of the Intensity of Deprivation in Urban Area', fontsize=20)
plt.show()

# %%
#Interactive Analysis

# %%
country.columns
# Out:
# Index(['ISO', 'Country', 'MPI Urban', 'Headcount Ratio Urban',
#        'Intensity of Deprivation Urban', 'MPI Rural', 'Headcount Ratio Rural',
#        'Intensity of Deprivation Rural'],
#       dtype='object')

# %%
@interact
def check_poverty(column=['Headcount Ratio Urban'], x=50):
    c=country[['Country', 'Headcount Ratio Urban']]
    c=c.sort_values(by= 'Headcount Ratio Urban', ascending=False)
    return c.loc[c[column]>x]
# Out:
# interactive(children=(Dropdown(description='column', options=('Headcount Ratio Urban',), value='Headcount Rati…

# %%
@interact 
def check_poverty(column=['Headcount Ratio Rural'], x=90.0):
    c=country[['Country','Headcount Ratio Rural']]
    c=c.sort_values(by='Headcount Ratio Rural', ascending=False)
    return c.loc[c[column]>x]
# Out:
# interactive(children=(Dropdown(description='column', options=('Headcount Ratio Rural',), value='Headcount Rati…

# %%
@interact
def check_poverty(column=['MPI Urban'], x=0.2):
    c=country[['Country','MPI Urban']]
    return c.loc[c[column]>x]
# Out:
# interactive(children=(Dropdown(description='column', options=('MPI Urban',), value='MPI Urban'), FloatSlider(v…

# %%
@interact
def check_poverty(column=['MPI Rural'], x=0.5):
    c=country[['Country','MPI Rural']]
    c=c.sort_values(by='MPI Rural', ascending=False)
    return c.loc[c[column]>x]
# Out:
# interactive(children=(Dropdown(description='column', options=('MPI Rural',), value='MPI Rural'), FloatSlider(v…

# %%
@interact
def check_poverty(column = 'Intensity of Deprivation Urban', x = 50.0):
    c = country[['Country','Intensity of Deprivation Urban']]
    return c.loc[c[column] > x]
# Out:
# interactive(children=(Text(value='Intensity of Deprivation Urban', description='column'), FloatSlider(value=50…

# %%
@interact
def check_poverty(column = 'Intensity of Deprivation Rural', x = 50.0):
    c = country[['Country','Intensity of Deprivation Rural']]
    return c.loc[c[column] > x]
# Out:
# interactive(children=(Text(value='Intensity of Deprivation Rural', description='column'), FloatSlider(value=50…

# %%
@interact
def check(column1=list(country.select_dtypes('number').columns),
         column2=list(country.select_dtypes('number').columns[1:])):
    print("Correlation is:", country[column1].corr(country[column2]))
# Out:
# interactive(children=(Dropdown(description='column1', options=('MPI Urban', 'Headcount Ratio Urban', 'Intensit…

# %%
@interact
def check(column1=list(country.select_dtypes('number').columns),
         column2=list(country.select_dtypes('number').columns[1:])):
    print("Covariation is:", country[column1].cov(country[column2]))
# Out:
# interactive(children=(Dropdown(description='column1', options=('MPI Urban', 'Headcount Ratio Urban', 'Intensit…

# %%
@interact
def check(column1=list(country.select_dtypes('number').columns)):
    print("The Maximum Value is:",country[column1].max())
# Out:
# interactive(children=(Dropdown(description='column1', options=('MPI Urban', 'Headcount Ratio Urban', 'Intensit…

# %%
@interact
def check(column1=list(country.select_dtypes('number').columns)):
    print("The Minimum Value is:",country[column1].min())
# Out:
# interactive(children=(Dropdown(description='column1', options=('MPI Urban', 'Headcount Ratio Urban', 'Intensit…

# %%
@interact
def check(column1=list(country.select_dtypes('number').columns)):
    print("The Average Value is:",country[column1].mean())
# Out:
# interactive(children=(Dropdown(description='column1', options=('MPI Urban', 'Headcount Ratio Urban', 'Intensit…

# %%
@interact
def check(column1=list(country.select_dtypes('number').columns)):
    print("The standard deviation is: ", country[column1].std())
# Out:
# interactive(children=(Dropdown(description='column1', options=('MPI Urban', 'Headcount Ratio Urban', 'Intensit…

# %% [markdown]
# ---

# %%
#Interactive Visualization

# %%
@interact_manual
def plot_scatter(column1=list(country.select_dtypes('number').columns),
                column2=list(country.select_dtypes('number').columns[1:]),
                color=['red','black','green','blue','crimson','yellow']):
    sns.scatterplot(country[column1], country[column2], color=color)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='column1', options=('MPI Urban', 'Headcount Ratio Urban', 'Intensit…

# %%
help(sns.scatterplot)
# Out:
# Help on function scatterplot in module seaborn.relational:
#
# scatterplot(x=None, y=None, hue=None, style=None, size=None, data=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, markers=True, style_order=None, x_bins=None, y_bins=None, units=None, estimator=None, ci=95, n_boot=1000, alpha='auto', x_jitter=None, y_jitter=None, legend='brief', ax=None, **kwargs)
#     Draw a scatter plot with possibility of several semantic groupings.
#
#     The relationship between ``x`` and ``y`` can be shown for different subsets
#     of the data using the ``hue``, ``size``, and ``style`` parameters. These
#     parameters control what visual semantics are used to identify the different
#     subsets. It is possible to show up to three dimensions independently by
#     using all three semantic types, but this style of plot can be hard to
#     interpret and is often ineffective. Using redundant semantics (i.e. both
# ...

# %%
plt.rcParams['figure.figsize']=(18, 6)
@interact_manual
def plot_bar(column1=list(country.select_dtypes('object').columns),
            column2=list(country.select_dtypes('number').columns)):
    sns.barplot(country[column1], country[column2])
    plt.xtricks(rotation=90)
# Out:
# interactive(children=(Dropdown(description='column1', options=('ISO', 'Country'), value='ISO'), Dropdown(descr…

# %% [markdown]
# ---

# %%
#Multi-dimensional Index on the Sub National Level

# %%
#Lets read another dataset

subnational=pd.read_csv('MPI_subnational.csv')

# %%
subnational.shape
# Out:
# (984, 8)

# %%
subnational.head()
# Out:
#   ISO country code      Country Sub-national region World region  \
# 0              AFG  Afghanistan          Badakhshan   South Asia
# 1              AFG  Afghanistan             Badghis   South Asia
# 2              AFG  Afghanistan             Baghlan   South Asia
# 3              AFG  Afghanistan               Balkh   South Asia
# 4              AFG  Afghanistan              Bamyan   South Asia
#
#    MPI National  MPI Regional  Headcount Ratio Regional  \
# 0         0.295         0.387                      67.5
# 1         0.295         0.466                      79.3
# 2         0.295         0.300                      59.7
# 3         0.295         0.301                      55.7
# 4         0.295         0.325                      61.0
#
#    Intensity of deprivation Regional
# 0                               57.3
# 1                               58.8
# 2                               50.3
# 3                               54.1
# 4                               53.3

# %%
subnational.tail()
# Out:
#     ISO country code   Country Sub-national region        World region  \
# 979              ZWE  Zimbabwe    Mashonaland West  Sub-Saharan Africa
# 980              ZWE  Zimbabwe            Masvingo  Sub-Saharan Africa
# 981              ZWE  Zimbabwe  Matabeleland North  Sub-Saharan Africa
# 982              ZWE  Zimbabwe  Matabeleland South  Sub-Saharan Africa
# 983              ZWE  Zimbabwe            Midlands  Sub-Saharan Africa
#
#      MPI National  MPI Regional  Headcount Ratio Regional  \
# 979         0.152         0.192                      43.7
# 980         0.152         0.174                      38.9
# 981         0.152         0.238                      53.4
# 982         0.152         0.164                      38.2
# 983         0.152         0.176                      40.5
#
#      Intensity of deprivation Regional
# 979                               44.1
# 980                               44.7
# 981                               44.5
# ...

# %%
subnational.sample(3)
# Out:
#     ISO country code    Country Sub-national region  \
# 840              SUR   Suriname           Marowijne
# 396              IDN  Indonesia     East Kalimantan
# 967              ZMB     Zambia             Luapula
#
#                     World region  MPI National  MPI Regional  \
# 840  Latin America and Caribbean         0.024         0.026
# 396    East Asia and the Pacific         0.066         0.058
# 967           Sub-Saharan Africa         0.281         0.392
#
#      Headcount Ratio Regional  Intensity of deprivation Regional
# 840                       6.7                               39.3
# 396                      14.1                               41.3
# 967                      75.9                               51.6

# %%
subnational.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ISO country code                   984 non-null    object
#  1   Country                            984 non-null    object
#  2   Sub-national region                984 non-null    object
#  3   World region                       984 non-null    object
#  4   MPI National                       984 non-null    float64
#  5   MPI Regional                       984 non-null    float64
#  6   Headcount Ratio Regional           984 non-null    float64
#  7   Intensity of deprivation Regional  983 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 61.6+ KB

# %%
subnational.dtypes
# Out:
# ISO country code                      object
# Country                               object
# Sub-national region                   object
# World region                          object
# MPI National                         float64
# MPI Regional                         float64
# Headcount Ratio Regional             float64
# Intensity of deprivation Regional    float64
# dtype: object

# %%
subnational.isnull().sum()
# Out:
# ISO country code                     0
# Country                              0
# Sub-national region                  0
# World region                         0
# MPI National                         0
# MPI Regional                         0
# Headcount Ratio Regional             0
# Intensity of deprivation Regional    1
# dtype: int64

# %%
subnational['Intensity of deprivation Regional']=subnational['Intensity of deprivation Regional'].fillna(0)
subnational.isnull().sum().sum()
# Out:
# 0

# %%
#Lets check the basic statistics of the data
x=subnational.describe()
x.style.bar(color='lightblue', align='mid')
# Out:
# <style  type="text/css" >
#     #T_62fe9292_b62b_11ea_9aef_72c94e85ea33row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#         }    #T_62fe9292_b62b_11ea_9aef_72c94e85ea33row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#         }    #T_62fe9292_b62b_11ea_9aef_72c94e85ea33row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#         }    #T_62fe9292_b62b_11ea_9aef_72c94e85ea33row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#         }    #T_62fe9292_b62b_11ea_9aef_72c94e85ea33row1_col0 {
#             width:  10em;
#              height:  80%;
# ...

# %%
#Lets check the correlation of the data
x=subnational.corr()
x.style.bar(color='orange', align='mid')
# Out:
# <style  type="text/css" >
#     #T_6306ef1c_b62b_11ea_be0a_72c94e85ea33row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 100.0%, transparent 100.0%);
#         }    #T_6306ef1c_b62b_11ea_be0a_72c94e85ea33row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 85.9%, transparent 85.9%);
#         }    #T_6306ef1c_b62b_11ea_be0a_72c94e85ea33row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 85.6%, transparent 85.6%);
#         }    #T_6306ef1c_b62b_11ea_be0a_72c94e85ea33row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,orange 80.5%, transparent 80.5%);
#         }    #T_6306ef1c_b62b_11ea_be0a_72c94e85ea33row1_col0 {
#             width:  10em;
#              height:  80%;
# ...

# %%
#Lets check the coefficient of variance f the data
x=subnational.cov()
x.style.bar(color='crimson', align='mid')
# Out:
# <style  type="text/css" >
#     #T_631a5d88_b62b_11ea_b841_72c94e85ea33row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,crimson 0.6%, transparent 0.6%);
#         }    #T_631a5d88_b62b_11ea_b841_72c94e85ea33row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,crimson 0.5%, transparent 0.5%);
#         }    #T_631a5d88_b62b_11ea_b841_72c94e85ea33row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,crimson 0.5%, transparent 0.5%);
#         }    #T_631a5d88_b62b_11ea_b841_72c94e85ea33row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,crimson 0.5%, transparent 0.5%);
#         }    #T_631a5d88_b62b_11ea_b841_72c94e85ea33row1_col0 {
#             width:  10em;
#              height:  80%;
# ...

# %%
plt.rcParams['figure.figsize']=(9, 6)
sns.heatmap(subnational.corr(),
           cmap='Blues',
           annot=True)
plt.title("correlation in the sub National data", fontsize=20)
plt.show()

# %%
plt.rcParams['figure.figsize']=(9, 6)
sns.heatmap(subnational.cov(), cmap='Blues', annot=True)
plt.title("Covariance in the sub National data", fontsize=20)
plt.show()

# %%
sns.pairplot(subnational)

# %% [markdown]
# ---

# %%
#Lets check the columns in the sub national and national data
print("Columns in the sub National Data:\n\n", subnational.columns)
# Out:
# Columns in the sub National Data:
#
#  Index(['ISO country code', 'Country', 'Sub-national region', 'World region',
#        'MPI National', 'MPI Regional', 'Headcount Ratio Regional',
#        'Intensity of deprivation Regional'],
#       dtype='object')

# %%
s=subnational[['World region','Country', 'MPI National']]
s=s.groupby(['World region'])
s=s.agg('mean')
s=s.sort_values(by='MPI National', ascending=False)
s.style.bar(color=['Silver'], align='mid')
# Out:
# <style  type="text/css" >
#     #T_69545fee_b62b_11ea_8c24_72c94e85ea33row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Silver 100.0%, transparent 100.0%);
#         }    #T_69545fee_b62b_11ea_8c24_72c94e85ea33row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Silver 63.0%, transparent 63.0%);
#         }    #T_69545fee_b62b_11ea_8c24_72c94e85ea33row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Silver 37.4%, transparent 37.4%);
#         }    #T_69545fee_b62b_11ea_8c24_72c94e85ea33row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Silver 33.4%, transparent 33.4%);
#         }    #T_69545fee_b62b_11ea_8c24_72c94e85ea33row4_col0 {
#             width:  10em;
#              height:  80%;
# ...

# %%
s = subnational[['World region','MPI Regional']]
s = s.groupby(['World region'])
s = s.agg('mean')
s = s.sort_values(by = 'MPI Regional', ascending = False)
s.style.bar(color = 'gold', align = 'mid')
# Out:
# <style  type="text/css" >
#     #T_7b60149c_b62b_11ea_930d_72c94e85ea33row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 100.0%, transparent 100.0%);
#         }    #T_7b60149c_b62b_11ea_930d_72c94e85ea33row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 65.1%, transparent 65.1%);
#         }    #T_7b60149c_b62b_11ea_930d_72c94e85ea33row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 40.4%, transparent 40.4%);
#         }    #T_7b60149c_b62b_11ea_930d_72c94e85ea33row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 34.2%, transparent 34.2%);
#         }    #T_7b60149c_b62b_11ea_930d_72c94e85ea33row4_col0 {
#             width:  10em;
#              height:  80%;
# ...

# %%
s = subnational[['World region','Headcount Ratio Regional']]
s = s.groupby(['World region'])
s = s.agg('mean')
s = s.sort_values(by = 'Headcount Ratio Regional', ascending = False)
s.style.bar(color = 'aqua', align = 'mid')
# Out:
# <style  type="text/css" >
#     #T_7e8e5900_b62b_11ea_b695_72c94e85ea33row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,aqua 100.0%, transparent 100.0%);
#         }    #T_7e8e5900_b62b_11ea_b695_72c94e85ea33row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,aqua 71.7%, transparent 71.7%);
#         }    #T_7e8e5900_b62b_11ea_b695_72c94e85ea33row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,aqua 46.0%, transparent 46.0%);
#         }    #T_7e8e5900_b62b_11ea_b695_72c94e85ea33row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,aqua 37.6%, transparent 37.6%);
#         }    #T_7e8e5900_b62b_11ea_b695_72c94e85ea33row4_col0 {
#             width:  10em;
#              height:  80%;
# ...

# %%
s = sub[['World region','Intensity of deprivation Regional']]
s = s.groupby(['World region'])
s = s.agg('mean')
s = s.sort_values(by = 'Intensity of deprivation Regional', ascending = False)
s.style.bar(color = 'lightgreen', align = 'mid')

# %% [markdown]
# ---

# %%
#Data Visualizations

# %%
plt.rcParams['figure.figsize']=(15, 10)
plt.style.use('fivethirtyeight')
sns.swarmplot(subnational['World region'],
              subnational['Intensity of deprivation Regional'],
              palette = 'summer')
plt.title('Intensity of deprivation in Different Regions of the World for Rural area',
         fontsize=20)
plt.show()

# %%
plt.rcParams['figure.figsize']=(15, 10)
plt.style.use('fivethirtyeight')
sns.violinplot(subnational['Country'][:60],
              subnational['MPI Regional'],
              palette='summer')
plt.title('Intensity of deprivation in Different Regions of the World for Rural area',
         fontsize=20)
plt.show()

# %%
plt.rcParams['figure.figsize']=(15,10)
plt.style.use('fivethirtyeight')
sns.boxenplot(subnational['World region'],
              subnational['Headcount Ratio Regional'], palette='Blues')
plt.title('Comparison of Headcount Ratio in Different Regions of World fpr Regional Area',
         fontsize=20)
plt.show()

# %%
plt.rcParams['figure.figsize']=(15, 10)
plt.style.use('fivethirtyeight')

sns.boxplot(subnational['World region'],
           subnational['MPI Regional'], palette='spring')
plt.title("Comparison of MPI in Different Regions of the World for Regional Areas", fontsize=20)
plt.show()

# %%
plt.rcParams['figure.figsize']=(15, 10)
plt.style.use('fivethirtyeight')
sns.barplot(subnational['World region'], subnational['MPI National'])
plt.title('Comparison of MPI in Different Regions of World, fontsize=20')
plt.show()

# %% [markdown]
# ---

# %%
#Interactive Analysis

# %%
@interact
def check(column=['Headcount Ratio Regional', 'Intensity of deprivation Regional'], x=95.0):
    return subnational.loc[subnational[column]>x]
# Out:
# interactive(children=(Dropdown(description='column', options=('Headcount Ratio Regional', 'Intensity of depriv…

# %%
@interact_manual
def bar_plot(column1=['World region'],
            column2=list(subnational.select_dtypes('number').columns),
             colors=['spring', 'Blues', 'Reds', 'copper']):
    sns.boxplot(subnational[column1], subnational[column2], palette=colors)
    plt.xticks(rotation=90)
# Out:
# interactive(children=(Dropdown(description='column1', options=('World region',), value='World region'), Dropdo…

# %%
@interact_manual
def bar_plot(column1 = list(subnational.select_dtypes('object').columns),
             column2 = list(subnational.select_dtypes('number').columns)):
    sns.barplot(subnational[column1][:100], subnational[column2])
    plt.xticks(rotation = 90)
# Out:
# interactive(children=(Dropdown(description='column1', options=('ISO country code', 'Country', 'Sub-national re…

# %%
@interact_manual
def plot_scatter(column1=list(subnational.select_dtypes('number').columns),
                column2=list(subnational.select_dtypes('number').columns[1:]),
                color=['red', 'black', 'green', 'yellow', 'blue']):
    sns.scatterplot(subnational[column1],subnational[column2], color=color)
    plt.show()
# Out:
# interactive(children=(Dropdown(description='column1', options=('MPI National', 'MPI Regional', 'Headcount Rati…
